# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/home/abbas/SZIC AI/Datasets/train.csv")
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test = pd.read_csv("/home/abbas/SZIC AI/Datasets/train.csv")
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
xtest = test[['OverallQual','1stFlrSF','GrLivArea','GarageCars','GarageArea']]
xtest.isnull().sum()
# Out:
# OverallQual    0
# 1stFlrSF       0
# GrLivArea      0
# GarageCars     0
# GarageArea     0
# dtype: int64

# %%
mean_car=xtest['GarageCars'].mean()
mean_car
# Out:
# 1.7671232876712328

# %%
xtest['GarageCars'].fillna(mean_car,inplace=True)
# Out:
# /tmp/ipykernel_6347/2903901290.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xtest['GarageCars'].fillna(mean_car,inplace=True)

# %%
mean_area=data['GarageArea'].mean()
mean_area
# Out:
# 472.9801369863014

# %%
xtest['GarageArea'].fillna(mean_area,inplace=True)
# Out:
# /tmp/ipykernel_6347/2583958227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xtest['GarageArea'].fillna(mean_area,inplace=True)

# %%
xtest.isnull().sum()
# Out:
# OverallQual    0
# 1stFlrSF       0
# GrLivArea      0
# GarageCars     0
# GarageArea     0
# dtype: int64

# %%
(data.corr()>0.4).sum()
# Out:
# Id                1
# MSSubClass        1
# LotFrontage       4
# LotArea           2
# OverallQual      13
# OverallCond       1
# YearBuilt         8
# YearRemodAdd      7
# MasVnrArea        3
# BsmtFinSF1        4
# BsmtFinSF2        1
# BsmtUnfSF         2
# TotalBsmtSF       9
# 1stFlrSF         11
# 2ndFlrSF          6
# LowQualFinSF      1
# GrLivArea        14
# BsmtFullBath      2
# BsmtHalfBath      1
# FullBath         11
# HalfBath          3
# BedroomAbvGr      4
# KitchenAbvGr      1
# TotRmsAbvGrd      8
# Fireplaces        4
# GarageYrBlt       8
# GarageCars       11
# GarageArea       10
# WoodDeckSF        1
# OpenPorchSF       1
# EnclosedPorch     1
# 3SsnPorch         1
# ScreenPorch       1
# PoolArea          1
# MiscVal           1
# MoSold            1
# YrSold            1
# SalePrice        14
# dtype: int64

# %%
fig = plt.figure(figsize=(30,25))
corr_mat = data.corr()
sns.heatmap(corr_mat,annot = True)
# Out:
# <AxesSubplot:>

# %%
data.shape
# Out:
# (1460, 81)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
DTree=DecisionTreeRegressor()
DTree.fit(x_train , y_train)
# Out:
# DecisionTreeRegressor()

# %%
DTree_Score=DTree.score(x_test,y_test)
DTree_Score
# Out:
# 0.7359755287260175

# %% [markdown]
# # KNN Regression

# %%
from sklearn.neighbors import KNeighborsRegressor
KNN=KNeighborsRegressor(n_neighbors=7)
KNN.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
KNN_Score=KNN.score(x_test,y_test)
KNN_Score
# Out:
# 0.608452451563585

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
Random_Forest=RandomForestRegressor()
Random_Forest.fit(x_train,y_train)
# Out:
# /tmp/ipykernel_6347/2472495851.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Random_Forest.fit(x_train,y_train)
# RandomForestRegressor()

# %%
Random_Forest_Score=Random_Forest.score(x_test,y_test)
Random_Forest_Score
# Out:
# 0.8317085470903833

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR
svm=SVR(kernel='linear')
svm.fit(x_train,y_train)
# Out:
# /home/abbas/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %%
SVM_Score=svm.score(x_test,y_test)
SVM_Score
# Out:
# 0.5264951929764232

# %% [markdown]
# # Univariate Regression

# %% [markdown]
# # Multivariate Regression

# %%
x = data[['OverallQual','1stFlrSF','GrLivArea','GarageCars','GarageArea']]
y = data[['SalePrice']]

# %%
from sklearn.linear_model import LinearRegression
lin = LinearRegression()

# %%
lin.fit(x,y)
# Out:
# LinearRegression()

# %%
lin.score(x,y)
# Out:
# 0.7566890226892562

# %%
lin.predict(xtest)
# Out:
# array([[206888.71728093],
#        [174142.13445394],
#        [213307.99106177],
#        ...,
#        [223387.58340374],
#        [116881.07245974],
#        [130585.08806477]])

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)

# %%
polyx = poly.fit_transform(x)

# %%
pxtest = poly.fit_transform(xtest)

# %%
lin.fit(polyx,y)
# Out:
# LinearRegression()

# %%
lin.score(polyx,y)
# Out:
# 0.8390184449690431

# %%
lin.predict(pxtest)
# Out:
# array([[197150.48614431],
#        [168733.15911586],
#        [206874.68043395],
#        ...,
#        [217658.33221631],
#        [127137.655509  ],
#        [137148.43823235]])

# %%
# Score for 9 features on Multivariate (Train:75% , Test:83%) test_size = 0.2
# Score for 9 features on Polynomial (Train:85% , Test:87%) test_size = 0.2
# Score for 5 features on Multivariate (Train:73% , Test:82%) test_size = 0.2
# Score for 5 features on Polynomial (Train:82% , Test:86%) test_size = 0.2

# %% [markdown]
# # 3) Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
sdt = ss.fit_transform(x)
sdtest = ss.fit_transform(xtest)

# %%
sdt
# Out:
# array([[ 0.65147924, -0.79343379,  0.37033344,  0.31172464,  0.35100032],
#        [-0.07183611,  0.25714043, -0.48251191,  0.31172464, -0.06073101],
#        [ 0.65147924, -0.62782603,  0.51501256,  0.31172464,  0.63172623],
#        ...,
#        [ 0.65147924,  0.06565646,  1.56964722, -1.02685765, -1.03391416],
#        [-0.79515147, -0.21898188, -0.83278768, -1.02685765, -1.09005935],
#        [-0.79515147,  0.2416147 , -0.49393395, -1.02685765, -0.9216238 ]])

# %%
sdtest
# Out:
# array([[ 0.65147924, -0.79343379,  0.37033344,  0.31172464,  0.35100032],
#        [-0.07183611,  0.25714043, -0.48251191,  0.31172464, -0.06073101],
#        [ 0.65147924, -0.62782603,  0.51501256,  0.31172464,  0.63172623],
#        ...,
#        [ 0.65147924,  0.06565646,  1.56964722, -1.02685765, -1.03391416],
#        [-0.79515147, -0.21898188, -0.83278768, -1.02685765, -1.09005935],
#        [-0.79515147,  0.2416147 , -0.49393395, -1.02685765, -0.9216238 ]])

# %%
lin.fit(sdt,y)
# Out:
# LinearRegression()

# %%
lin.score(sdt,y)
# Out:
# 0.7566890226892562

# %% [markdown]
# # Polynomial

# %%
polystd = poly.fit_transform(sdt)

# %%
polysdtest = poly.fit_transform(sdtest)

# %%
lin.fit(polystd,y)
# Out:
# LinearRegression()

# %%
lin.score(polystd,y)
# Out:
# 0.8390184449690431

# %%
lin.predict(polysdtest)
# Out:
# array([[197150.48614734],
#        [168733.15911449],
#        [206874.68043608],
#        ...,
#        [217658.33222128],
#        [127137.65550885],
#        [137148.4382311 ]])
